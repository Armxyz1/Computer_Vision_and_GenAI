# %%
# !git config --global credential.helper store

# %%
# !python -m pip install huggingface_hub
# !huggingface-cli login
# Out:
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.23.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub) (4.12.0)
# Collecting colorama (from tqdm>=4.42.1->huggingface_hub)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface_hub) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface_hub) (2024.2.2)
# Downloading huggingface_hub-0.23.3-py3-none-any.whl (401 kB)
#    ---------------------------------------- 0.0/401.7 kB ? eta -:--:--
#    ----------------- ---------------------- 174.1/401.7 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  399.4/401.7 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 401.7/401.7 kB 3.6 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama, huggingface_hub
# Successfully installed colorama-0.4.6 huggingface_hub-0.23.3
# WARNING: Ignoring invalid distribution -uggingface-hub (c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -uggingface-hub (c:\users\armaan khetarpaul\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nvitop 1.3.2 requires psutil>=5.6.6, which is not installed.
# wandb 0.16.6 requires psutil>=5.0.0, which is not installed.
# redis-om 0.2.2 requires pydantic<2.5.0,>=1.10.2, but you have pydantic 2.7.1 which is incompatible.
# sotopia 0.0.8 requires pydantic==1.10.12, but you have pydantic 2.7.1 which is incompatible.
# ^C

# %%
import os
# !pip install -U -q autotrain-advanced
# Out:
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Armaan Khetarpaul\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\~aml'.
#   You can safely remove it manually.
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\users\\armaan khetarpaul\\appdata\\local\\packages\\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\\localcache\\local-packages\\python311\\scripts\\huggingface-cli.exe'
# Check the permissions.

# %% [markdown]
# # Restart Session if not done, after installation, go to runtime -> restart session

# %%
import os

#@markdown ---
#@markdown #### Project Config
project_name = 'Black' # @param {type:"string"}
model_name = 'stabilityai/stable-diffusion-xl-base-1.0' # @param ["stabilityai/stable-diffusion-xl-base-1.0", "runwayml/stable-diffusion-v1-5", "stabilityai/stable-diffusion-2-1", "stabilityai/stable-diffusion-2-1-base"]
prompt = 'black person' # @param {type: "string"}

#@markdown ---
#@markdown #### Push to Hub?
#@markdown Use these only if you want to push your trained model to a private repo in your Hugging Face Account
#@markdown If you dont use these, the model will be saved in Google Colab and you are required to download it manually.
#@markdown Please enter your Hugging Face write token. The trained model will be saved to your Hugging Face account.
#@markdown You can find your token here: https://huggingface.co/settings/tokens
push_to_hub = True # @param ["False", "True"] {type:"raw"}
hf_token = "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" #@param {type:"string"}
repo_id = "Armxyz1/Black" #@param {type:"string"}

#@markdown ---
#@markdown #### Hyperparameters
learning_rate = 5e-5 # @param {type:"number"}
num_steps = 20 #@param {type:"number"}
batch_size = 32 # @param {type:"slider", min:1, max:32, step:1}
gradient_accumulation = 4 # @param {type:"slider", min:1, max:32, step:1}
resolution = 1024 # @param {type:"slider", min:128, max:1024, step:128}
use_8bit_adam = False # @param ["False", "True"] {type:"raw"}
use_xformers = False # @param ["False", "True"] {type:"raw"}
use_fp16 = True # @param ["False", "True"] {type:"raw"}
train_text_encoder = False # @param ["False", "True"] {type:"raw"}
gradient_checkpointing = True # @param ["False", "True"] {type:"raw"}

os.environ["PROJECT_NAME"] = project_name
os.environ["MODEL_NAME"] = model_name
os.environ["PROMPT"] = prompt
os.environ["PUSH_TO_HUB"] = str(push_to_hub)
os.environ["HF_TOKEN"] = hf_token
os.environ["REPO_ID"] = repo_id
os.environ["LEARNING_RATE"] = str(learning_rate)
os.environ["NUM_STEPS"] = str(num_steps)
os.environ["BATCH_SIZE"] = str(batch_size)
os.environ["GRADIENT_ACCUMULATION"] = str(gradient_accumulation)
os.environ["RESOLUTION"] = str(resolution)
os.environ["USE_8BIT_ADAM"] = str(use_8bit_adam)
os.environ["USE_XFORMERS"] = str(use_xformers)
os.environ["USE_FP16"] = str(use_fp16)
os.environ["TRAIN_TEXT_ENCODER"] = str(train_text_encoder)
os.environ["GRADIENT_CHECKPOINTING"] = str(gradient_checkpointing)

# %% [markdown]
# # Save your training images to folder named as images, no need to run the next cell as it will use the images in the tutorial

# %%
# !gdown "1_dUGj1Tfl4nIIBIB0D2eTga-lBuPet22"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1_dUGj1Tfl4nIIBIB0D2eTga-lBuPet22
# From (redirected): https://drive.google.com/uc?id=1_dUGj1Tfl4nIIBIB0D2eTga-lBuPet22&confirm=t&uuid=fbd0df5e-1cdb-4ad0-a6cc-76cb15475fb6
# To: /content/images.zip
# 100% 80.2M/80.2M [00:04<00:00, 19.8MB/s]

# %%
import zipfile
with zipfile.ZipFile("/content/images.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/")

# %%
# !autotrain dreambooth --help
# Out:
# usage: autotrain <command> [<args>] dreambooth [-h] [--train] [--deploy] [--inference]
#                                                [--username USERNAME]
#                                                [--backend {spaces-a10g-large,spaces-a10g-small,spaces-a100-large,spaces-t4-medium,spaces-t4-small,spaces-cpu-upgrade,spaces-cpu-basic,spaces-l4x1,spaces-l4x4,spaces-a10g-largex2,spaces-a10g-largex4,dgx-a100,dgx-2a100,dgx-4a100,dgx-8a100,ep-aws-useast1-s,ep-aws-useast1-m,ep-aws-useast1-l,ep-aws-useast1-xl,ep-aws-useast1-2xl,ep-aws-useast1-4xl,ep-aws-useast1-8xl,nvcf-l40sx1,nvcf-h100x1,nvcf-h100x2,nvcf-h100x4,nvcf-h100x8,local-ui,local,local-cli}]
#                                                [--token TOKEN] [--push-to-hub] --model MODEL
#                                                --project-name PROJECT_NAME [--data-path DATA_PATH]
#                                                [--train-split TRAIN_SPLIT]
#                                                [--valid-split VALID_SPLIT]
#                                                [--batch-size BATCH_SIZE] [--seed SEED]
#                                                [--epochs EPOCHS]
#                                                [--gradient-accumulation GRADIENT_ACCUMULATION]
#                                                [--disable-gradient-checkpointing] [--lr LR]
#                                                [--log {none,wandb,tensorboard}]
#                                                [--revision REVISION] [--tokenizer TOKENIZER]
#                                                --image-path IMAGE_PATH
#                                                [--class-image-path CLASS_IMAGE_PATH] --prompt
#                                                PROMPT [--class-prompt CLASS_PROMPT]
#                                                [--num-class-images NUM_CLASS_IMAGES]
#                                                [--class-labels-conditioning CLASS_LABELS_CONDITIONING]
#                                                [--prior-preservation]
#                                                [--prior-loss-weight PRIOR_LOSS_WEIGHT]
#                                                --resolution RESOLUTION [--center-crop]
#                                                [--train-text-encoder]
#                                                [--sample-batch-size SAMPLE_BATCH_SIZE]
#                                                [--num-steps NUM_STEPS]
#                                                [--checkpointing-steps CHECKPOINTING_STEPS]
#                                                [--resume-from-checkpoint RESUME_FROM_CHECKPOINT]
#                                                [--scale-lr] [--scheduler SCHEDULER]
#                                                [--warmup-steps WARMUP_STEPS]
#                                                [--num-cycles NUM_CYCLES] [--lr-power LR_POWER]
#                                                [--dataloader-num-workers DATALOADER_NUM_WORKERS]
#                                                [--use-8bit-adam] [--adam-beta1 ADAM_BETA1]
#                                                [--adam-beta2 ADAM_BETA2]
#                                                [--adam-weight-decay ADAM_WEIGHT_DECAY]
#                                                [--adam-epsilon ADAM_EPSILON]
#                                                [--max-grad-norm MAX_GRAD_NORM] [--allow-tf32]
#                                                [--prior-generation-precision PRIOR_GENERATION_PRECISION]
#                                                [--local-rank LOCAL_RANK] [--xformers]
#                                                [--pre-compute-text-embeddings]
#                                                [--tokenizer-max-length TOKENIZER_MAX_LENGTH]
#                                                [--text-encoder-use-attention-mask] [--rank RANK]
#                                                [--xl] [--mixed-precision MIXED_PRECISION]
#                                                [--validation-prompt VALIDATION_PROMPT]
#                                                [--num-validation-images NUM_VALIDATION_IMAGES]
#                                                [--validation-epochs VALIDATION_EPOCHS]
#                                                [--checkpoints-total-limit CHECKPOINTS_TOTAL_LIMIT]
#                                                [--validation-images VALIDATION_IMAGES] [--logging]
#
# ✨ Run AutoTrain DreamBooth Training
#
# options:
#   -h, --help            show this help message and exit
#   --train               Command to train the model
#   --deploy              Command to deploy the model (limited availability)
#   --inference           Command to run inference (limited availability)
#   --username USERNAME   Hugging Face Hub Username
#   --backend {spaces-a10g-large,spaces-a10g-small,spaces-a100-large,spaces-t4-medium,spaces-t4-small,spaces-cpu-upgrade,spaces-cpu-basic,spaces-l4x1,spaces-l4x4,spaces-a10g-largex2,spaces-a10g-largex4,dgx-a100,dgx-2a100,dgx-4a100,dgx-8a100,ep-aws-useast1-s,ep-aws-useast1-m,ep-aws-useast1-l,ep-aws-useast1-xl,ep-aws-useast1-2xl,ep-aws-useast1-4xl,ep-aws-useast1-8xl,nvcf-l40sx1,nvcf-h100x1,nvcf-h100x2,nvcf-h100x4,nvcf-h100x8,local-ui,local,local-cli}
#                         Backend to use: default or spaces. Spaces backend requires push_to_hub &
#                         username. Advanced users only.
#   --token TOKEN         Your Hugging Face API token. Token must have write access to the model
#                         hub.
#   --push-to-hub         Push to hub after training will push the trained model to the Hugging Face
#                         model hub.
#   --model MODEL         Base model to use for training
#   --project-name PROJECT_NAME
#                         Output directory / repo id for trained model (must be unique on hub)
#   --data-path DATA_PATH
#                         Train dataset to use. When using cli, this should be a directory path
#                         containing training and validation data in appropriate formats
#   --train-split TRAIN_SPLIT
#                         Train dataset split to use
#   --valid-split VALID_SPLIT
#                         Validation dataset split to use
#   --batch-size BATCH_SIZE
#                         Training batch size to use
#   --seed SEED           Random seed for reproducibility
#   --epochs EPOCHS       Number of training epochs
#   --gradient-accumulation GRADIENT_ACCUMULATION
#                         Gradient accumulation steps
#   --disable-gradient-checkpointing
#                         Disable gradient checkpointing
#   --lr LR               Learning rate
#   --log {none,wandb,tensorboard}
#                         Use experiment tracking
#   --revision REVISION   Model revision to use for training
#   --tokenizer TOKENIZER
#                         Tokenizer to use for training
#   --image-path IMAGE_PATH
#                         Path to the images
#   --class-image-path CLASS_IMAGE_PATH
#                         Path to the class images
#   --prompt PROMPT       Instance prompt
#   --class-prompt CLASS_PROMPT
#                         Class prompt
#   --num-class-images NUM_CLASS_IMAGES
#                         Number of class images
#   --class-labels-conditioning CLASS_LABELS_CONDITIONING
#                         Class labels conditioning
#   --prior-preservation  With prior preservation
#   --prior-loss-weight PRIOR_LOSS_WEIGHT
#                         Prior loss weight
#   --resolution RESOLUTION
#                         Resolution
#   --center-crop         Center crop
#   --train-text-encoder  Train text encoder
#   --sample-batch-size SAMPLE_BATCH_SIZE
#                         Sample batch size
#   --num-steps NUM_STEPS
#                         Max train steps
#   --checkpointing-steps CHECKPOINTING_STEPS
#                         Checkpointing steps
#   --resume-from-checkpoint RESUME_FROM_CHECKPOINT
#                         Resume from checkpoint
#   --scale-lr            Scale learning rate
#   --scheduler SCHEDULER
#                         Learning rate scheduler
#   --warmup-steps WARMUP_STEPS
#                         Learning rate warmup steps
#   --num-cycles NUM_CYCLES
#                         Learning rate num cycles
#   --lr-power LR_POWER   Learning rate power
#   --dataloader-num-workers DATALOADER_NUM_WORKERS
#                         Dataloader num workers
#   --use-8bit-adam       Use 8bit adam
#   --adam-beta1 ADAM_BETA1
#                         Adam beta 1
#   --adam-beta2 ADAM_BETA2
#                         Adam beta 2
#   --adam-weight-decay ADAM_WEIGHT_DECAY
#                         Adam weight decay
#   --adam-epsilon ADAM_EPSILON
#                         Adam epsilon
#   --max-grad-norm MAX_GRAD_NORM
#                         Max grad norm
#   --allow-tf32          Allow TF32
#   --prior-generation-precision PRIOR_GENERATION_PRECISION
#                         Prior generation precision
#   --local-rank LOCAL_RANK
#                         Local rank
#   --xformers            Enable xformers memory efficient attention
#   --pre-compute-text-embeddings
#                         Pre compute text embeddings
#   --tokenizer-max-length TOKENIZER_MAX_LENGTH
#                         Tokenizer max length
#   --text-encoder-use-attention-mask
#                         Text encoder use attention mask
#   --rank RANK           Rank
#   --xl                  XL
#   --mixed-precision MIXED_PRECISION
#                         mixed precision, fp16, bf16, none
#   --validation-prompt VALIDATION_PROMPT
#                         Validation prompt
#   --num-validation-images NUM_VALIDATION_IMAGES
#                         Number of validation images
#   --validation-epochs VALIDATION_EPOCHS
#                         Validation epochs
#   --checkpoints-total-limit CHECKPOINTS_TOTAL_LIMIT
#                         Checkpoints total limit
#   --validation-images VALIDATION_IMAGES
#                         Validation images
#   --logging             Logging using tensorboard

# %%
# !autotrain dreambooth \
--model ${MODEL_NAME} \
--username Armxyz1 \
--project-name ${PROJECT_NAME} \
--image-path images/ \
--prompt  "${PROMPT}" \
--resolution ${RESOLUTION} \
--batch-size ${BATCH_SIZE} \
--num-steps ${NUM_STEPS} \
--gradient-accumulation ${GRADIENT_ACCUMULATION} \
--lr ${LEARNING_RATE} \
--mixed-precision fp16 \
$( [[ "$USE_XFORMERS" == "True" ]] && echo "--xformers" ) \
$( [[ "$TRAIN_TEXT_ENCODER" == "True" ]] && echo "--train-text-encoder" ) \
$( [[ "$USE_8BIT_ADAM" == "True" ]] && echo "--use-8bit-adam" ) \
$( [[ "$GRADIENT_CHECKPOINTING" == "False" ]] && echo "--disable-gradient-checkpointing" ) \
$( [[ "$PUSH_TO_HUB" == "True" ]] && echo "--push-to-hub --token ${HF_TOKEN}" )
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6577.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1371.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5111.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1851.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2360.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8300.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7186.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8055.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6164.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10971.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8904.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8647.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/784.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5474.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/57.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/9677.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8102.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4669.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7633.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5162.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/9676.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7854.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5368.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11903.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2975.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/438.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8968.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10319.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7474.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3040.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/13255.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8463.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4926.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5229.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4415.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/160.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7721.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/13482.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12890.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11715.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/13573.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5178.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/885.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2152.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/537.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/9989.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5110.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1476.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10487.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2759.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12296.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7034.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4430.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3277.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1486.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/13577.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1697.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2840.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6336.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7427.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6233.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3010.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12952.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7989.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4503.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4031.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8107.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1028.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2959.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10587.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10567.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8948.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2836.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8155.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7707.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4888.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1395.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/13562.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1919.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6833.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12857.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12802.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4807.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12326.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5374.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5366.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5585.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6115.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/116.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/964.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/13136.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8141.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11433.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5964.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12584.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/9914.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/9181.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1599.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4213.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11338.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11553.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12538.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8701.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12624.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2715.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5155.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11302.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5531.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12447.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7006.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11845.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5920.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11633.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12376.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4981.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6186.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4775.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/329.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6727.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5103.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3100.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7074.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2725.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4953.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/9516.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2032.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8091.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3586.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6306.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/13054.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8121.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4009.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8687.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3547.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10814.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7786.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8982.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2144.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10089.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5339.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/13752.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12010.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7620.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/730.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7892.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7450.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4521.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2365.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/147.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/13739.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8448.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12941.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11262.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1903.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2507.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1015.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8051.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3270.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/9955.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5739.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8168.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2009.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7263.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4882.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1817.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6175.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6169.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7638.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10240.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7607.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3754.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2785.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11047.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7233.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4294.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3486.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5797.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2706.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/932.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/258.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/9367.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10468.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2502.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1997.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5087.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/13497.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/9690.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/13070.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10289.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10312.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4499.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3017.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10360.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11855.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7094.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8374.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10220.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4829.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3137.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12650.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10826.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8578.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12310.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8504.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4653.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2248.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1929.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6865.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10332.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4535.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8528.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8230.jpg
# INFO     | 2024-06-07 08:34:55 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# ...
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6463.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8739.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2376.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10976.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3428.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1445.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8175.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6558.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/9839.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10732.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6451.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8389.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/2145.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5850.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5348.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7281.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6770.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6284.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/92.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1588.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/655.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10830.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3827.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7643.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10922.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3661.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/13670.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/267.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/9610.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/12565.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11002.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8691.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6024.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/922.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/10261.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4111.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4483.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11710.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4472.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7059.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/1802.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/7412.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6204.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8363.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11331.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11172.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/8282.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/3232.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/5669.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/6808.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/4752.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:67 - Saving concept images
# INFO     | 2024-06-07 08:34:59 | autotrain.preprocessor.dreambooth:_save_concept_images:68 - images/11240.jpg
# INFO     | 2024-06-07 08:34:59 | autotrain.backends.local:create:8 - Starting local training...
# INFO     | 2024-06-07 08:34:59 | autotrain.commands:launch_command:386 - ['python', '-m', 'autotrain.trainers.dreambooth', '--training_config', 'Black/training_params.json']
# INFO     | 2024-06-07 08:34:59 | autotrain.commands:launch_command:387 - {'model': 'stabilityai/stable-diffusion-xl-base-1.0', 'vae_model': None, 'revision': None, 'tokenizer': None, 'image_path': 'Black/autotrain-data', 'class_image_path': None, 'prompt': 'black person', 'class_prompt': None, 'num_class_images': 100, 'class_labels_conditioning': None, 'prior_preservation': False, 'prior_loss_weight': 1.0, 'project_name': 'Black', 'seed': 42, 'resolution': 1024, 'center_crop': False, 'train_text_encoder': False, 'batch_size': 32, 'sample_batch_size': 4, 'epochs': 1, 'num_steps': 20, 'checkpointing_steps': 100000, 'resume_from_checkpoint': None, 'gradient_accumulation': 4, 'disable_gradient_checkpointing': False, 'lr': 5e-05, 'scale_lr': False, 'scheduler': 'constant', 'warmup_steps': 0, 'num_cycles': 1, 'lr_power': 1.0, 'dataloader_num_workers': 0, 'use_8bit_adam': False, 'adam_beta1': 0.9, 'adam_beta2': 0.999, 'adam_weight_decay': 0.01, 'adam_epsilon': 1e-08, 'max_grad_norm': 1.0, 'allow_tf32': False, 'prior_generation_precision': None, 'local_rank': -1, 'xformers': False, 'pre_compute_text_embeddings': False, 'tokenizer_max_length': None, 'text_encoder_use_attention_mask': False, 'rank': 4, 'xl': True, 'mixed_precision': 'fp16', 'token': '*****', 'push_to_hub': True, 'username': 'Armxyz1', 'validation_prompt': None, 'num_validation_images': 4, 'validation_epochs': 50, 'checkpoints_total_limit': None, 'validation_images': None, 'logging': False}
# WARNING  | 2024-06-07 08:35:04 | __main__:train:39 - Failed to download dataset: 404 Client Error. (Request ID: Root=1-6662c638-1b2858ae68aa97f31af696f7;51e50105-fc2f-4070-84a1-a649a2da4f69)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/Black/autotrain-data/revision/main.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated.
# tokenizer/tokenizer_config.json: 100% 737/737 [00:00<00:00, 4.46MB/s]
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 15.3MB/s]
# tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 27.1MB/s]
# tokenizer/special_tokens_map.json: 100% 472/472 [00:00<00:00, 3.73MB/s]
# tokenizer_2/tokenizer_config.json: 100% 725/725 [00:00<00:00, 5.34MB/s]
# tokenizer_2/special_tokens_map.json: 100% 460/460 [00:00<00:00, 3.83MB/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# text_encoder/config.json: 100% 565/565 [00:00<00:00, 2.95MB/s]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# text_encoder_2/config.json: 100% 575/575 [00:00<00:00, 3.70MB/s]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# model_index.json: 100% 609/609 [00:00<00:00, 3.69MB/s]
# scheduler/scheduler_config.json: 100% 479/479 [00:00<00:00, 3.27MB/s]
# {'rescale_betas_zero_snr', 'clip_sample_range', 'dynamic_thresholding_ratio', 'variance_type', 'thresholding'} was not found in config. Values will be initialized to default values.
# model.safetensors: 100% 492M/492M [00:02<00:00, 180MB/s]
# model.safetensors: 100% 2.78G/2.78G [00:17<00:00, 160MB/s]
# vae/config.json: 100% 642/642 [00:00<00:00, 4.74MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:01<00:00, 178MB/s]
# {'latents_std', 'latents_mean'} was not found in config. Values will be initialized to default values.
# unet/config.json: 100% 1.68k/1.68k [00:00<00:00, 11.2MB/s]
# diffusion_pytorch_model.safetensors: 100% 10.3G/10.3G [02:22<00:00, 72.0MB/s]
# {'dropout', 'attention_type', 'reverse_transformer_layers_per_block'} was not found in config. Values will be initialized to default values.
# INFO     | 2024-06-07 08:39:14 | autotrain.cli.run_dreambooth:run:393 - Job ID: 1467

# %% [markdown]
# # Inference

# %%
from diffusers import DiffusionPipeline
import torch

from diffusers import DiffusionPipeline, AutoencoderKL

vae = AutoencoderKL.from_pretrained("madebyollin/sdxl-vae-fp16-fix", torch_dtype=torch.float16)
pipe = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    vae=vae,
    torch_dtype=torch.float16,
    variant="fp16",
    use_safetensors=True
)
pipe.load_lora_weights("Armxyz1/Black")
pipe.to("cuda")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
import torch

# %%
prompt = "photo of a boy, sks shirt, ISO 5000"
neg_prompt = "out of frame, lowres, text, error, cropped, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, out of frame, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions, cloned face, disfigured"

pipe(
    prompt=prompt,
    negative_prompt=neg_prompt,
    guidance_scale=12.5,
    num_inference_steps=30,
    num_images_per_prompt=1,
    generator=torch.manual_seed(128)
).images[0]

# %%
prompt = "photo of a boy, sks shirt"
neg_prompt = "out of frame, lowres, text, error, cropped, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, out of frame, extra fingers, mutated hands, poorly drawn hands, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions, extra limbs, cloned face, disfigured"

pipe(
    prompt=prompt,
    negative_prompt=neg_prompt,
    guidance_scale=7.5,
    num_inference_steps=30,
    num_images_per_prompt=1
).images[0]

# %%
prompt = "photo of a girl wearing an sks shirt, photoshoot"
neg_prompt = "out of frame, lowres, text, error, cropped, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, out of frame, extra fingers, mutated hands, poorly drawn hands, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions, extra limbs, cloned face, disfigured"

pipe(
    prompt=prompt,
    negative_prompt=neg_prompt,
    guidance_scale=7.5,
    num_inference_steps=50,
    num_images_per_prompt=1
).images[0]

# %%
prompt = "photo of a girl wearing an sks shirt, photoshoot"
neg_prompt = "out of frame, lowres, text, error, cropped, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, out of frame, extra fingers, mutated hands, poorly drawn hands, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions, extra limbs, cloned face, disfigured"

pipe(
    prompt=prompt,
    negative_prompt=neg_prompt,
    guidance_scale=7.5,
    num_inference_steps=50,
    num_images_per_prompt=1
).images[0]

# %%
prompt = "an sks shirt in a wardrobe"
neg_prompt = "out of frame, lowres, text, error, cropped, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, out of frame, extra fingers, mutated hands, poorly drawn hands, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions, extra limbs, cloned face, disfigured"

pipe(
    prompt=prompt,
    negative_prompt=neg_prompt,
    guidance_scale=7.5,
    num_inference_steps=30,
    num_images_per_prompt=1
).images[0]

# %%
prompt = "a girl wearing an sks shirt, in streets of Paris"
neg_prompt = "out of frame, lowres, text, error, cropped, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, out of frame, extra fingers, mutated hands, poorly drawn hands, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions, extra limbs, cloned face, disfigured"

pipe(
    prompt=prompt,
    negative_prompt=neg_prompt,
    guidance_scale=7.5,
    num_inference_steps=30,
    num_images_per_prompt=1
).images[0]

# %%
prompt = "a couple wearing sks shirts"
neg_prompt = "out of frame, lowres, text, error, cropped, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, out of frame, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions, cloned face, disfigured"

pipe(
    prompt=prompt,
    negative_prompt=neg_prompt,
    guidance_scale=12.5,
    num_inference_steps=30,
    num_images_per_prompt=1
).images[0]

# %%
prompt = "a couple wearing sks shirts"
neg_prompt = "out of frame, lowres, text, error, cropped, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, out of frame, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions, cloned face, disfigured"

pipe(
    prompt=prompt,
    negative_prompt=neg_prompt,
    guidance_scale=15,
    num_inference_steps=30,
    num_images_per_prompt=1,
    generator=torch.manual_seed(254584)
).images[0]

# %%
prompt = "a couple wearing sks shirts"
neg_prompt = "out of frame, lowres, text, error, cropped, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, out of frame, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions, cloned face, disfigured"

pipe(
    prompt=prompt,
    negative_prompt=neg_prompt,
    guidance_scale=15,
    num_inference_steps=30,
    num_images_per_prompt=1,
    generator=torch.manual_seed(45646584)
).images[0]

# %%
prompt = "photo of a steve jobs wearing an sks shirt"
neg_prompt = "out of frame, lowres, text, error, cropped, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, out of frame, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions, cloned face, disfigured"

pipe(
    prompt=prompt,
    negative_prompt=neg_prompt,
    guidance_scale=7.5,
    num_inference_steps=50,
    num_images_per_prompt=1
).images[0]

# %%
prompt = "photo of a steve jobs wearing an sks shirt"
neg_prompt = "out of frame, lowres, text, error, cropped, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, out of frame, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions, cloned face, disfigured"

pipe(
    prompt=prompt,
    negative_prompt=neg_prompt,
    guidance_scale=10,
    num_inference_steps=30,
    num_images_per_prompt=1,
    generator=torch.manual_seed(33432453)
).images[0]

# %%
prompt = "photo of a steve jobs wearing an sks shirt"
neg_prompt = "out of frame, lowres, text, error, cropped, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, out of frame, poorly drawn face, mutation, deformed, blurry, bad anatomy, bad proportions, cloned face, disfigured"

pipe(
    prompt=prompt,
    negative_prompt=neg_prompt,
    guidance_scale=10,
    num_inference_steps=30,
    num_images_per_prompt=1,
    generator=torch.manual_seed(334374456543)
).images[0]
